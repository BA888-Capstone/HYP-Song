# %%
pip install librosa essentia
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Collecting essentia
#   Downloading essentia-2.1b6.dev1110-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.25.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from essentia) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from essentia) (6.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
# Installing collected packages: essentia
# Successfully installed essentia-2.1b6.dev1110

# %%
import os
import shutil

# Parent directory containing the 10 folders
parent_dir = '/content/drive/MyDrive/genres_original'

# Destination directory where all audio files will be copied
destination_dir = '/content/drive/MyDrive/all_audio'

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

# Iterate over each subfolder in the parent directory
for subdir_name in os.listdir(parent_dir):
    subdir_path = os.path.join(parent_dir, subdir_name)

    # Check if it is a directory
    if os.path.isdir(subdir_path):
        # Iterate over each file in the subfolder
        for file_name in os.listdir(subdir_path):
            # Full file path
            source_file = os.path.join(subdir_path, file_name)

            # Check if it's a file (not a directory)
            if os.path.isfile(source_file):
                # Destination file path
                destination_file = os.path.join(destination_dir, file_name)

                # Copy the file
                shutil.copy(source_file, destination_file)

print("Audio files have been successfully copied to the destination directory.")
# Out:
# Audio files have been successfully copied to the destination directory.

# %%
import librosa
import essentia
import essentia.standard as ess
import numpy as np

# Load the audio file using librosa
file_path = '/content/blues.00000.wav'
y, sr = librosa.load(file_path)

# Using librosa to extract features
# Tempo
tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
print('Tempo:', tempo)

# Energy (Root Mean Square Energy)
rmse = librosa.feature.rms(y=y)
energy = np.mean(rmse)
print('Energy:', energy)

# Loudness (average perceptual loudness)
S = np.abs(librosa.stft(y))
loudness = librosa.amplitude_to_db(S, ref=np.max)
avg_loudness = np.mean(loudness)
print('Loudness:', avg_loudness)

# Load the audio file using essentia
loader = ess.MonoLoader(filename=file_path)
audio = loader()

# Extract features using Essentia
extractor = ess.MusicExtractor(lowlevelStats=['mean', 'stdev'])

# Extract features
features, feature_metadata = extractor(file_path)

# Print features from Essentia
print('Danceability:', features['rhythm.danceability'])
print('Loudness (Essentia):', features['lowlevel.average_loudness'])
# Out:
# Tempo: [123.046875]
# Energy: 0.13018432
# Loudness: -59.057514
# Danceability: 1.5240553617477417
# Loudness (Essentia): 0.9618877172470093

# %%
import os
import librosa
import essentia
import essentia.standard as ess
import numpy as np
import pandas as pd

def extract_features(file_path):
    try:
        # Load the audio file using librosa
        y, sr = librosa.load(file_path)

        # Using librosa to extract features
        # Tempo
        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)

        # Energy (Root Mean Square Energy)
        rmse = librosa.feature.rms(y=y)
        energy = np.mean(rmse)

        # Loudness (average perceptual loudness)
        S = np.abs(librosa.stft(y))
        loudness = librosa.amplitude_to_db(S, ref=np.max)
        avg_loudness = np.mean(loudness)

        # Load the audio file using essentia
        loader = ess.MonoLoader(filename=file_path)
        audio = loader()

        # Extract features using Essentia
        extractor = ess.MusicExtractor(lowlevelStats=['mean', 'stdev'])
        features, feature_metadata = extractor(file_path)

        # Collect features
        feature_dict = {
            'file': file_path,
            'tempo': tempo,
            'energy': energy,
            'loudness_librosa': avg_loudness,
            'danceability': features['rhythm.danceability'],
            'loudness_essentia': features['lowlevel.average_loudness'],
        }

        return feature_dict

    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None

def process_audio_folder(folder_path):
    results = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(('.wav', '.mp3')):
                file_path = os.path.join(root, file)
                features = extract_features(file_path)
                if features:
                    results.append(features)
                    print(features)  # Print the features for each file
    return results

# Path to the folder containing audio files
folder_path = '/content/drive/MyDrive/all_audio'

# Process the folder and extract features
audio_features = process_audio_folder(folder_path)

# Convert to DataFrame
df = pd.DataFrame(audio_features)

# Display the DataFrame
print(df)
# Out:
# {'file': '/content/drive/MyDrive/all_audio/jazz.00097.wav', 'tempo': array([86.1328125]), 'energy': 0.021176668, 'loudness_librosa': -73.37764, 'danceability': 1.1507781744003296, 'loudness_essentia': 0.7815133929252625}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00068.wav', 'tempo': array([73.828125]), 'energy': 0.09949384, 'loudness_librosa': -64.89327, 'danceability': 0.9578545689582825, 'loudness_essentia': 0.6659838557243347}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00040.wav', 'tempo': array([99.38401442]), 'energy': 0.13801351, 'loudness_librosa': -63.844234, 'danceability': 1.209382176399231, 'loudness_essentia': 0.9654508233070374}
# <ipython-input-1-a4640cd5fed7>:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing /content/drive/MyDrive/all_audio/jazz.00054.wav:
# {'file': '/content/drive/MyDrive/all_audio/jazz.00059.wav', 'tempo': array([107.66601562]), 'energy': 0.18228659, 'loudness_librosa': -63.5907, 'danceability': 1.3352532386779785, 'loudness_essentia': 0.9569924473762512}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00071.wav', 'tempo': array([151.99908088]), 'energy': 0.10030232, 'loudness_librosa': -65.64958, 'danceability': 0.9038035869598389, 'loudness_essentia': 0.888090968132019}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00045.wav', 'tempo': array([73.828125]), 'energy': 0.10030164, 'loudness_librosa': -66.014694, 'danceability': 0.9038109183311462, 'loudness_essentia': 0.8881118297576904}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00051.wav', 'tempo': array([95.703125]), 'energy': 0.069750376, 'loudness_librosa': -66.51852, 'danceability': 1.0147353410720825, 'loudness_essentia': 0.5248919129371643}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00079.wav', 'tempo': array([107.66601562]), 'energy': 0.06982318, 'loudness_librosa': -50.857292, 'danceability': 1.5060815811157227, 'loudness_essentia': 0.9718244075775146}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00047.wav', 'tempo': array([69.83741554]), 'energy': 0.05389259, 'loudness_librosa': -56.38571, 'danceability': 1.2853245735168457, 'loudness_essentia': 0.9271425604820251}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00053.wav', 'tempo': array([95.703125]), 'energy': 0.13001709, 'loudness_librosa': -57.03449, 'danceability': 1.4618955850601196, 'loudness_essentia': 0.9522128105163574}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00084.wav', 'tempo': array([123.046875]), 'energy': 0.05166333, 'loudness_librosa': -48.720417, 'danceability': 1.0654760599136353, 'loudness_essentia': 0.9186962246894836}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00090.wav', 'tempo': array([135.99917763]), 'energy': 0.06135448, 'loudness_librosa': -56.252007, 'danceability': 0.9877243041992188, 'loudness_essentia': 0.9153194427490234}
# {'file': '/content/drive/MyDrive/all_audio/jazz.00091.wav', 'tempo': array([83.35433468]), 'energy': 0.040916957, 'loudness_librosa': -60.83643, 'danceability': 0.8117534518241882, 'loudness_essentia': 0.48846831917762756}
# {'file': '/content/drive/MyDrive/all_audio/jazz.
# {'file': '/content/drive/MyDrive/all_audio/metal.00030.wav', 'tempo': array([129.19921875]), 'energy': 0.23018019, 'loudness_librosa': -57.05974, 'danceability': 1.6749303340911865, 'loudness_essentia': 0.9519426226615906}
# {'file': '/content/drive/MyDrive/all_audio/metal.00008.wav', 'tempo': array([117.45383523]), 'energy': 0.058365826, 'loudness_librosa': -48.425922, 'danceability': 1.503799557685852, 'loudness_essentia': 0.9813333749771118}
# {'file': '/content/drive/MyDrive/all_audio/metal.00034.wav', 'tempo': array([161.49902344]), 'energy': 0.09046083, 'loudness_librosa': -46.286, 'danceability': 1.1326135396957397, 'loudness_essentia': 0.965097188949585}
# {'file': '/content/drive/MyDrive/all_audio/metal.00020.wav', 'tempo': array([99.38401442]), 'energy': 0.11726673, 'loudness_librosa': -46.63869, 'danceability': 1.2798616886138916, 'loudness_essentia': 0.9567692875862122}
# {'file': '/content/drive/MyDrive/all_audio/metal.00021.wav', 'tempo': array([107.66601562]), 'energy': 0.10841584, 'loudness_librosa': -47.49088, 'danceability': 1.703810214996338, 'loudness_essentia': 0.9707411527633667}
# {'file': '/content/drive/MyDrive/all_audio/metal.00035.wav', 'tempo': array([117.45383523]), 'energy': 0.27069268, 'loudness_librosa': -49.131157, 'danceability': 1.0282479524612427, 'loudness_essentia': 0.9706807136535645}
# {'file': '/content/drive/MyDrive/all_audio/metal.00009.wav', 'tempo': array([112.34714674]), 'energy': 0.3126573, 'loudness_librosa': -46.811172, 'danceability': 1.3043532371520996, 'loudness_essentia': 0.9817177057266235}
# {'file': '/content/drive/MyDrive/all_audio/metal.00023.wav', 'tempo': array([143.5546875]), 'energy': 0.19521451, 'loudness_librosa': -49.31463, 'danceability': 1.7765719890594482, 'loudness_essentia': 0.9819700121879578}
# {'file': '/content/drive/MyDrive/all_audio/metal.00037.wav', 'tempo': array([135.99917763]), 'energy': 0.11196359, 'loudness_librosa': -47.91646, 'danceability': 1.239768385887146, 'loudness_essentia': 0.9738455414772034}
# {'file': '/content/drive/MyDrive/all_audio/metal.00036.wav', 'tempo': array([143.5546875]), 'energy': 0.112159654, 'loudness_librosa': -46.24793, 'danceability': 1.2956697940826416, 'loudness_essentia': 0.9635462760925293}
# {'file': '/content/drive/MyDrive/all_audio/metal.00022.wav', 'tempo': array([135.99917763]), 'energy': 0.19874765, 'loudness_librosa': -51.22664, 'danceability': 1.3223695755004883, 'loudness_essentia': 0.9715114235877991}
# {'file': '/content/drive/MyDrive/all_audio/metal.00095.wav', 'tempo': array([151.99908088]), 'energy': 0.18539381, 'loudness_librosa': -50.837624, 'danceability': 1.7352546453475952, 'loudness_essentia': 0.9677404165267944}
# {'file': '/content/drive/MyDrive/all_audio/metal.00083.wav', 'tempo': array([117.45383523]), 'energy': 0.2085754, 'loudness_librosa': -48.851852, 'danceability': 1.6765803098678589, 'loudness_essentia': 0.9792060256004333}
# {'file': '/content/drive/MyDrive/all_audio/metal.00097.wav', 'tempo': array([112.34714674]), 'energy': 0.18602574, 'loudness_librosa': -54.968517, 'danceability': 1.1234097480773926, 'loudness_essentia': 0.9483057260513306}
# {'file': '/content/drive/MyDrive/all_audio/metal.00068.wav', 'tempo': array([161.49902344]), 'energy': 0.09829889, 'loudness_librosa': -49.69327, 'danceability': 1.1756529808044434, 'loudness_essentia': 0.9307155609130859}
# {'file': '/content/drive/MyDrive/all_audio/metal.00040.wav', 'tempo': array([107.66601562]), 'energy': 0.10457902, 'loudness_librosa': -45.496246, 'danceability': 1.2916380167007446, 'loudness_essentia': 0.9794612526893616}
# {'file': '/content/drive/MyDrive/all_audio/metal.00054.wav', 'tempo': array([123.046875]), 'energy': 0.20701885, 'loudness_librosa': -43.17716, 'danceability': 1.1956524848937988, 'loudness_essentia': 0.9821328520774841}
# {'file': '/content/drive/MyDrive/all_audio/metal.00055.wav', 'tempo': array([172.265625]), 'energy': 0.23246978, 'loudness_librosa': -42.225513, 'danceability': 1.4254289865493774, 'loudness_essentia': 0.9807789921760559}
# {'file': '/content/drive/MyDrive/all_audio/metal.00041.wav', 'tempo': array([117.45383523]), 'energy': 0.09754965, 'loudness_librosa': -46.66685, 'danceability': 1.8022087812423706, 'loudness_essentia': 0.9825754761695862}
# {'file': '/content/drive/MyDrive/all_audio/metal.00069.wav', 'tempo': array([161.49902344]), 'energy': 0.17353307, 'loudness_librosa': -54.447525, 'danceability': 1.5952098369598389, 'loudness_essentia': 0.9837551116943359}
# {'file': '/content/drive/MyDrive/all_audio/metal.00096.wav', 'tempo': array([161.49902344]), 'energy': 0.18817005, 'loudness_librosa': -50.840687, 'danceability': 1.540040135383606, 'loudness_essentia': 0.9636296629905701}
# {'file': '/content/drive/MyDrive/all_audio/metal.00082.wav', 'tempo': array([123.046875]), 'energy': 0.13156159, 'loudness_librosa': -48.54917, 'danceability': 1.552433967590332, 'loudness_essentia': 0.9527320861816406}
# {'file': '/content/drive/MyDrive/all_audio/metal.00026.wav', 'tempo': array([129.19921875]), 'energy': 0.13815899, 'loudness_librosa': -45.315746, 'danceability': 1.6199688911437988, 'loudness_essentia': 0.9811366200447083}
# {'file': '/content/drive/MyDrive/all_audio/metal.00032.wav', 'tempo': array([117.45383523]), 'energy': 0.13645852, 'loudness_librosa': -47.953217, 'danceability': 1.122255563735962, 'loudness_essentia': 0.9836322069168091}
# {'file': '/content/drive/MyDrive/all_audio/metal.00033.wav', 'tempo': array([123.046875]), 'energy': 0.25668892, 'loudness_librosa': -53.84172, 'danceability': 1.696880578994751, 'loudness_essentia': 0.9735278487205505}
# {'file': '/content/drive/MyDrive/all_audio/metal.00027.wav', 'tempo': array([129.19921875]), 'energy': 0.16501737, 'loudness_librosa': -46.519466, 'danceability': 1.3932965993881226, 'loudness_essentia': 0.9770960211753845}
# {'file': '/content/drive/MyDrive/all_audio/metal.00031.wav', 'tempo': array([135.99917763]), 'energy': 0.22039165, 'loudness_librosa': -46.089478, 'danceability': 1.8444093465805054, 'loudness_essentia': 0.9816052913665771}
# {'file': '/content/drive/MyDrive/all_audio/metal.00091.wav', 'tempo': array([92.28515625]), 'energy': 0.11595993, 'loudness_librosa': -50.805523, 'danceability': 1.090916633605957, 'loudness_essentia': 0.8856273889541626}
# {'file': '/content/drive/MyDrive/all_audio/metal.00085.wav', 'tempo': array([103.359375]), 'energy': 0.1518885, 'loudness_librosa': -48.231018, 'danceability': 1.2222459316253662, 'loudness_essentia': 0.9256113171577454}
# {'file': '/content/drive/MyDrive/all_audio/metal.00052.wav', 'tempo': array([161.49902344]), 'energy': 0.23981513, 'loudness_librosa': -45.408527, 'danceability': 1.6029871702194214, 'loudness_essentia': 0.9829662442207336}
# {'file': '/content/drive/MyDrive/all_audio/metal.00046.wav', 'tempo': array([117.45383523]), 'energy': 0.21236151, 'loudness_librosa': -43.572502, 'danceability': 1.3872532844543457, 'loudness_essentia': 0.9842525720596313}
# {'file': '/content/drive/MyDrive/all_audio/metal.00047.wav', 'tempo': array([103.359375]), 'energy': 0.21747482, 'loudness_librosa': -42.733547, 'danceability': 1.1694656610488892, 'loudness_essentia': 0.9790734648704529}
# {'file': '/content/drive/MyDrive/all_audio/metal.00053.wav', 'tempo': array([123.046875]), 'energy': 0.22736318, 'loudness_librosa': -46.0072, 'danceability': 1.2376232147216797, 'loudness_essentia': 0.9638674259185791}
# {'file': '/content/drive/MyDrive/all_audio/metal.00084.wav', 'tempo': array([151.99908088]), 'energy': 0.22971004, 'loudness_librosa': -47.34481, 'danceability': 1.1521072387695312, 'loudness_essentia': 0.9304486513137817}
# {'file': '/content/drive/MyDrive/all_audio/metal.00090.wav', 'tempo': array([89.10290948]), 'energy': 0.14654946, 'loudness_librosa': -51.984413, 'danceability': 1.347589135169983, 'loudness_essentia': 0.9830459356307983}
# {'file': '/content/drive/MyDrive/all_audio/metal.00094.wav', 'tempo': array([161.49902344]), 'energy': 0.09046083, 'loudness_librosa': -46.286, 'danceability': 1.1326135396957397, 'loudness_essentia': 0.965097188949585}
# {'file': '/content/drive/MyDrive/all_audio/metal.00080.wav', 'tempo': array([161.49902344]), 'energy': 0.13984975, 'loudness_librosa': -50.81722, 'danceability': 1.422613501548767, 'loudness_essentia': 0.9354953169822693}
# {'file': '/content/drive/MyDrive/all_audio/metal.00057.wav', 'tempo': array([129.19921875]), 'energy': 0.20710796, 'loudness_librosa': -47.316563, 'danceability': 1.394162654876709, 'loudness_essentia': 0.9794265627861023}
# {'file': '/content/drive/MyDrive/all_audio/metal.00043.wav', 'tempo': array([95.703125]), 'energy': 0.09044641, 'loudness_librosa': -46.67384, 'danceability': 1.1723822355270386, 'loudness_essentia': 0.9671844244003296}
# {'file': '/content/drive/MyDrive/all_audio/metal.00042.wav', 'tempo': array([129.19921875]), 'energy': 0.09362838, 'loudness_librosa': -47.22415, 'danceability': 1.252951741218567, 'loudness_essentia': 0.97489994764328}
# {'file': '/content/drive/MyDrive/all_audio/metal.00056.wav', 'tempo': array([107.66601562]), 'energy': 0.24282901, 'loudness_librosa': -44.770393, 'danceability': 1.334073781967163, 'loudness_essentia': 0.9709551930427551}
# {'file': '/content/drive/MyDrive/all_audio/metal.00081.wav', 'tempo': array([151.99908088]), 'energy': 0.19033647, 'loudness_librosa': -47.836884, 'danceability': 1.3155460357666016, 'loudness_essentia': 0.9804384112358093}
# {'file': '/content/drive/MyDrive/all_audio/metal.00061.wav', 'tempo': array([107.66601562]), 'energy': 0.10457902, 'loudness_librosa': -45.496246, 'danceability': 1.2916380167007446, 'loudness_essentia': 0.9794612526893616}
# {'file': '/content/drive/MyDrive/all_audio/metal.00075.wav', 'tempo': array([112.34714674]), 'energy': 0.24464075, 'loudness_librosa': -53.6272, 'danceability': 1.0355898141860962, 'loudness_essentia': 0.8857043981552124}
# {'file': '/content/drive/MyDrive/all_audio/metal.00074.wav', 'tempo': array([123.046875]), 'energy': 0.0408314, 'loudness_librosa': -48.792118, 'danceability': 1.1643481254577637, 'loudness_essentia': 0.9539006948471069}
# {'file': '/content/drive/MyDrive/all_audio/metal.00060.wav', 'tempo': array([89.10290948]), 'energy': 0.1257114, 'loudness_librosa': -47.300793, 'danceability': 1.741087794303894, 'loudness_essentia': 0.9770573377609253}
# {'file': '/content/drive/MyDrive/all_audio/metal.00048.wav', 'tempo': array([107.66601562]), 'energy': 0.22439936, 'loudness_librosa': -43.351658, 'danceability': 1.0883045196533203, 'loudness_essentia': 0.9726858139038086}
# {'file': '/content/drive/MyDrive/all_audio/metal.00086.wav', 'tempo': array([123.046875]), 'energy': 0.08825739, 'loudness_librosa': -45.578636, 'danceability': 1.26198148727417, 'loudness_essentia': 0.962527871131897}
# {'file': '/content/drive/MyDrive/all_audio/metal.00092.wav', 'tempo': array([117.45383523]), 'energy': 0.16623126, 'loudness_librosa': -51.046093, 'danceability': 1.8644134998321533, 'loudness_essentia': 0.9813964366912842}
# {'file': '/content/drive/MyDrive/all_audio/metal.00045.wav', 'tempo': array([61.5234375]), 'energy': 0.08802084, 'loudness_librosa': -50.875473, 'danceability': 0.9730850458145142, 'loudness_essentia': 0.8969234824180603}
# {'file': '/content/drive/MyDrive/all_audio/metal.00051.wav', 'tempo': array([107.66601562]), 'energy': 0.22616892, 'loudness_librosa': -42.459694, 'danceability': 1.1750270128250122, 'loudness_essentia': 0.9637709856033325}
# {'file': '/content/drive/MyDrive/all_audio/metal.00079.wav', 'tempo': array([123.046875]), 'energy': 0.12733027, 'loudness_librosa': -49.214478, 'danceability': 1.4129014015197754, 'loudness_essentia': 0.9627519249916077}
# {'file': '/content/drive/MyDrive/all_audio/metal.00078.wav', 'tempo': array([99.38401442]), 'energy': 0.2694679, 'loudness_librosa': -46.92526, 'danceability': 1.5797890424728394, 'loudness_essentia': 0.9744141101837158}
# {'file': '/content/drive/MyDrive/all_audio/metal.00050.wav', 'tempo': array([112.34714674]), 'energy': 0.24894612, 'loudness_librosa': -43.44158, 'danceability': 1.3762240409851074, 'loudness_essentia': 0.9819634556770325}
# {'file': '/content/drive/MyDrive/all_audio/metal.00044.wav', 'tempo': array([117.45383523]), 'energy': 0.095366985, 'loudness_librosa': -46.707626, 'danceability': 1.2128863334655762, 'loudness_essentia': 0.9720859527587891}
# {'file': '/content/drive/MyDrive/all_audio/metal.00093.wav', 'tempo': array([172.265625]), 'energy': 0.091984704, 'loudness_librosa': -48.942204, 'danceability': 1.5209813117980957, 'loudness_essentia': 0.9781463146209717}
# {'file': '/content/drive/MyDrive/all_audio/metal.00087.wav', 'tempo': array([95.703125]), 'energy': 0.2671389, 'loudness_librosa': -42.16672, 'danceability': 1.400734782218933, 'loudness_essentia': 0.9798903465270996}
# {'file': '/content/drive/MyDrive/all_audio/metal.00059.wav', 'tempo': array([99.38401442]), 'energy': 0.18228553, 'loudness_librosa': -46.15322, 'danceability': 1.4651901721954346, 'loudness_essentia': 0.9764963984489441}
# {'file': '/content/drive/MyDrive/all_audio/metal.00071.wav', 'tempo': array([86.1328125]), 'energy': 0.1152983, 'loudness_librosa': -48.408314, 'danceability': 1.4054386615753174, 'loudness_essentia': 0.9710052609443665}
# {'file': '/content/drive/MyDrive/all_audio/metal.00065.wav', 'tempo': array([117.45383523]), 'energy': 0.095366985, 'loudness_librosa': -46.707626, 'danceability': 1.2128863334655762, 'loudness_essentia': 0.9720859527587891}
# {'file': '/content/drive/MyDrive/all_audio/metal.00098.wav', 'tempo': array([151.99908088]), 'energy': 0.13896145, 'loudness_librosa': -56.135834, 'danceability': 1.5242197513580322, 'loudness_essentia': 0.9538689255714417}
# {'file': '/content/drive/MyDrive/all_audio/metal.00073.wav', 'tempo': array([143.5546875]), 'energy': 0.2933532, 'loudness_librosa': -47.490765, 'danceability': 1.5239027738571167, 'loudness_essentia': 0.9795620441436768}
# {'file': '/content/drive/MyDrive/all_audio/metal.00067.wav', 'tempo': array([135.99917763]), 'energy': 0.13622084, 'loudness_librosa': -50.77482, 'danceability': 2.0957260131835938, 'loudness_essentia': 0.9855425357818604}
# {'file': '/content/drive/MyDrive/all_audio/metal.00066.wav', 'tempo': array([61.5234375]), 'energy': 0.08802084, 'loudness_librosa': -50.875473, 'danceability': 0.9730850458145142, 'loudness_essentia': 0.8969234824180603}
# {'file': '/content/drive/MyDrive/all_audio/metal.00072.wav', 'tempo': array([123.046875]), 'energy': 0.19426143, 'loudness_librosa': -48.51504, 'danceability': 2.2395408153533936, 'loudness_essentia': 0.9867227673530579}
# {'file': '/content/drive/MyDrive/all_audio/metal.00099.wav', 'tempo': array([143.5546875]), 'energy': 0.17008242, 'loudness_librosa': -53.969505, 'danceability': 1.5433937311172485, 'loudness_essentia': 0.963066577911377}
# {'file': '/content/drive/MyDrive/all_audio/metal.00089.wav', 'tempo': array([151.99908088]), 'energy': 0.26595938, 'loudness_librosa': -58.686665, 'danceability': 1.0036307573318481, 'loudness_essentia': 0.9587474465370178}
# {'file': '/content/drive/MyDrive/all_audio/metal.00076.wav', 'tempo': array([143.5546875]), 'energy': 0.09689618, 'loudness_librosa': -50.790543, 'danceability': 1.1448768377304077, 'loudness_essentia': 0.9184158444404602}
# {'file': '/content/drive/MyDrive/all_audio/metal.00062.wav', 'tempo': array([117.45383523]), 'energy': 0.09754965, 'loudness_librosa': -46.66685, 'danceability': 1.8022087812423706, 'loudness_essentia': 0.9825754761695862}
# {'file': '/content/drive/MyDrive/all_audio/metal.00063.wav', 'tempo': array([129.19921875]), 'energy': 0.09362838, 'loudness_librosa': -47.22415, 'danceability': 1.252951741218567, 'loudness_essentia': 0.97489994764328}
# {'file': '/content/drive/MyDrive/all_audio/metal.00077.wav', 'tempo': array([151.99908088]), 'energy': 0.14906156, 'loudness_librosa': -43.826237, 'danceability': 1.151725172996521, 'loudness_essentia': 0.9697185158729553}
# {'file': '/content/drive/MyDrive/all_audio/metal.00088.wav', 'tempo': array([117.45383523]), 'energy': 0.13327341, 'loudness_librosa': -58.237392, 'danceability': 1.7765859365463257, 'loudness_essentia': 0.974341869354248}
# {'file': '/content/drive/MyDrive/all_audio/metal.00049.wav', 'tempo': array([99.38401442]), 'energy': 0.21749426, 'loudness_librosa': -42.974716, 'danceability': 1.5290992259979248, 'loudness_essentia': 0.9850476980209351}
# {'file': '/content/drive/MyDrive/all_audio/metal.00005.wav', 'tempo': array([151.99908088]), 'energy': 0.12173561, 'loudness_librosa': -49.61989, 'danceability': 1.7140344381332397, 'loudness_essentia': 0.9763768315315247}
# {'file': '/content/drive/MyDrive/all_audio/metal.00011.wav', 'tempo': array([161.49902344]), 'energy': 0.23059025, 'loudness_librosa': -43.746807, 'danceability': 1.2835062742233276, 'loudness_essentia': 0.9845095276832581}
# {'file': '/content/drive/MyDrive/all_audio/metal.00029.wav', 'tempo': array([123.046875]), 'energy': 0.08897911, 'loudness_librosa': -46.407333, 'danceability': 1.7380064725875854, 'loudness_essentia': 0.9789741039276123}
# {'file': '/content/drive/MyDrive/all_audio/metal.00015.wav', 'tempo': array([172.265625]), 'energy': 0.110896595, 'loudness_librosa': -43.81778, 'danceability': 1.3090460300445557, 'loudness_essentia': 0.9783901572227478}
# {'file': '/content/drive/MyDrive/all_audio/metal.00001.wav', 'tempo': array([78.30255682]), 'energy': 0.09723437, 'loudness_librosa': -42.35363, 'danceability': 1.1754071712493896, 'loudness_essentia': 0.9587068557739258}
# {'file': '/content/drive/MyDrive/all_audio/metal.00000.wav', 'tempo': array([95.703125]), 'energy': 0.11605348, 'loudness_librosa': -42.453636, 'danceability': 1.2619458436965942, 'loudness_essentia': 0.9741630554199219}
# {'file': '/content/drive/MyDrive/all_audio/metal.00014.wav', 'tempo': array([151.99908088]), 'energy': 0.07754347, 'loudness_librosa': -45.71862, 'danceability': 1.0610851049423218, 'loudness_essentia': 0.949334979057312}
# {'file': '/content/drive/MyDrive/all_audio/metal.00028.wav', 'tempo': array([135.99917763]), 'energy': 0.14405736, 'loudness_librosa': -42.070187, 'danceability': 1.4967252016067505, 'loudness_essentia': 0.9855237603187561}
# {'file': '/content/drive/MyDrive/all_audio/metal.00002.wav', 'tempo': array([112.34714674]), 'energy': 0.13272823, 'loudness_librosa': -47.74782, 'danceability': 1.3874180316925049, 'loudness_essentia': 0.9764248132705688}
# {'file': '/content/drive/MyDrive/all_audio/metal.00016.wav', 'tempo': array([92.28515625]), 'energy': 0.26962695, 'loudness_librosa': -45.374134, 'danceability': 1.3255327939987183, 'loudness_essentia': 0.9766886234283447}
# {'file': '/content/drive/MyDrive/all_audio/metal.00017.wav', 'tempo': array([107.66601562]), 'energy': 0.11373729, 'loudness_librosa': -44.208252, 'danceability': 1.9559406042099, 'loudness_essentia': 0.9737904667854309}
# {'file': '/content/drive/MyDrive/all_audio/metal.00003.wav', 'tempo': array([99.38401442]), 'energy': 0.15011945, 'loudness_librosa': -46.120132, 'danceability': 1.2091461420059204, 'loudness_essentia': 0.9606428742408752}
# {'file': '/content/drive/MyDrive/all_audio/metal.00064.wav', 'tempo': array([95.703125]), 'energy': 0.09044641, 'loudness_librosa': -46.67384, 'danceability': 1.1723822355270386, 'loudness_essentia': 0.9671844244003296}
# {'file': '/content/drive/MyDrive/all_audio/metal.00070.wav', 'tempo': array([117.45383523]), 'energy': 0.048833318, 'loudness_librosa': -53.69027, 'danceability': 1.2198772430419922, 'loudness_essentia': 0.7892231345176697}
# {'file': '/content/drive/MyDrive/all_audio/metal.00058.wav', 'tempo': array([143.5546875]), 'energy': 0.18441163, 'loudness_librosa': -46.09564, 'danceability': 1.0841495990753174, 'loudness_essentia': 0.9763575196266174}
# {'file': '/content/drive/MyDrive/all_audio/metal.00007.wav', 'tempo': array([151.99908088]), 'energy': 0.06945514, 'loudness_librosa': -45.1617, 'danceability': 2.5085995197296143, 'loudness_essentia': 0.9850339293479919}
# {'file': '/content/drive/MyDrive/all_audio/metal.00013.wav', 'tempo': array([135.99917763]), 'energy': 0.0862796, 'loudness_librosa': -42.876175, 'danceability': 1.1372346878051758, 'loudness_essentia': 0.9843416213989258}
# {'file': '/content/drive/MyDrive/all_audio/metal.00012.wav', 'tempo': array([172.265625]), 'energy': 0.11425508, 'loudness_librosa': -43.424744, 'danceability': 1.6261025667190552, 'loudness_essentia': 0.9863162636756897}
# {'file': '/content/drive/MyDrive/all_audio/metal.00006.wav', 'tempo': array([123.046875]), 'energy': 0.050436046, 'loudness_librosa': -43.915867, 'danceability': 1.247732162475586, 'loudness_essentia': 0.9746612906455994}
# {'file': '/content/drive/MyDrive/all_audio/metal.00010.wav', 'tempo': array([184.5703125]), 'energy': 0.11807427, 'loudness_librosa': -42.820873, 'danceability': 1.494575023651123, 'loudness_essentia': 0.9857078790664673}
# {'file': '/content/drive/MyDrive/all_audio/metal.00004.wav', 'tempo': array([135.99917763]), 'energy': 0.063436955, 'loudness_librosa': -41.24137, 'danceability': 1.2238249778747559, 'loudness_essentia': 0.9833365082740784}
# {'file': '/content/drive/MyDrive/all_audio/metal.00038.wav', 'tempo': array([95.703125]), 'energy': 0.14582604, 'loudness_librosa': -56.881577, 'danceability': 0.9521507620811462, 'loudness_essentia': 0.8748865127563477}
# {'file': '/content/drive/MyDrive/all_audio/metal.00039.wav', 'tempo': array([117.45383523]), 'energy': 0.15425298, 'loudness_librosa': -57.53654, 'danceability': 0.9599437713623047, 'loudness_essentia': 0.8277690410614014}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00040.wav', 'tempo': array([92.28515625]), 'energy': 0.03904713, 'loudness_librosa': -62.20542, 'danceability': 0.9215483665466309, 'loudness_essentia': 0.7591308951377869}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00054.wav', 'tempo': array([143.5546875]), 'energy': 0.09683505, 'loudness_librosa': -56.9369, 'danceability': 1.262822151184082, 'loudness_essentia': 0.9428369402885437}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00083.wav', 'tempo': array([129.19921875]), 'energy': 0.056750834, 'loudness_librosa': -67.452415, 'danceability': 0.8631746768951416, 'loudness_essentia': 0.5242800116539001}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00097.wav', 'tempo': array([161.49902344]), 'energy': 0.1106856, 'loudness_librosa': -57.192383, 'danceability': 0.9561913013458252, 'loudness_essentia': 0.8062611818313599}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00081.wav', 'tempo': array([99.38401442]), 'energy': 0.17930189, 'loudness_librosa': -58.22559, 'danceability': 2.668006658554077, 'loudness_essentia': 0.9775381684303284}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00095.wav', 'tempo': array([123.046875]), 'energy': 0.1622456, 'loudness_librosa': -49.98047, 'danceability': 2.020954132080078, 'loudness_essentia': 0.9691925048828125}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00042.wav', 'tempo': array([123.046875]), 'energy': 0.07124089, 'loudness_librosa': -57.082355, 'danceability': 1.3994628190994263, 'loudness_essentia': 0.9631354212760925}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00056.wav', 'tempo': array([161.49902344]), 'energy': 0.10047588, 'loudness_librosa': -55.557384, 'danceability': 1.2571873664855957, 'loudness_essentia': 0.9325721263885498}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00057.wav', 'tempo': array([95.703125]), 'energy': 0.10329819, 'loudness_librosa': -57.11887, 'danceability': 1.175487995147705, 'loudness_essentia': 0.8174372911453247}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00043.wav', 'tempo': array([151.99908088]), 'energy': 0.1106082, 'loudness_librosa': -61.415108, 'danceability': 1.3421998023986816, 'loudness_essentia': 0.8945060968399048}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00094.wav', 'tempo': array([129.19921875]), 'energy': 0.13466951, 'loudness_librosa': -50.67327, 'danceability': 1.638065218925476, 'loudness_essentia': 0.9734487533569336}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00080.wav', 'tempo': array([99.38401442]), 'energy': 0.19564289, 'loudness_librosa': -57.765823, 'danceability': 2.6064975261688232, 'loudness_essentia': 0.9772307872772217}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00093.wav', 'tempo': array([89.10290948]), 'energy': 0.10708073, 'loudness_librosa': -55.47718, 'danceability': 1.2391184568405151, 'loudness_essentia': 0.9524359107017517}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00087.wav', 'tempo': array([83.35433468]), 'energy': 0.20773205, 'loudness_librosa': -55.832367, 'danceability': 1.436381220817566, 'loudness_essentia': 0.9363002181053162}
# {'file': '/content/drive/MyDrive/all_audio/reggae.00078.wav', 'tempo': array([161.49902344]), 'energy': 0.09431865, 'loudness_librosa': -54.002483, 'danceability': 1.6927202939987183, 'loudness_essentia': 0.9819186925888062}
# ...
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00094.wav', 'tempo': array([151.99908088]), 'energy': 0.11072535, 'loudness_librosa': -60.317726, 'danceability': 1.8238681554794312, 'loudness_essentia': 0.9683509469032288}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00080.wav', 'tempo': array([95.703125]), 'energy': 0.14131808, 'loudness_librosa': -41.31327, 'danceability': 1.979671597480774, 'loudness_essentia': 0.981062114238739}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.

# {'file': '/content/drive/MyDrive/all_audio/hiphop.00006.wav', 'tempo': array([99.38401442]), 'energy': 0.27054507, 'loudness_librosa': -53.210056, 'danceability': 1.3975367546081543, 'loudness_essentia': 0.9575151205062866}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00010.wav', 'tempo': array([95.703125]), 'energy': 0.17160548, 'loudness_librosa': -53.367588, 'danceability': 1.6618860960006714, 'loudness_essentia': 0.956716001033783}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00004.wav', 'tempo': array([95.703125]), 'energy': 0.20046541, 'loudness_librosa': -60.06544, 'danceability': 1.575762391090393, 'loudness_essentia': 0.9547989368438721}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00038.wav', 'tempo': array([184.5703125]), 'energy': 0.2698501, 'loudness_librosa': -54.542233, 'danceability': 1.3212080001831055, 'loudness_essentia': 0.9554862380027771}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00039.wav', 'tempo': array([184.5703125]), 'energy': 0.18449508, 'loudness_librosa': -55.309654, 'danceability': 1.2924572229385376, 'loudness_essentia': 0.9428751468658447}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00005.wav', 'tempo': array([71.77734375]), 'energy': 0.26158613, 'loudness_librosa': -49.798508, 'danceability': 1.8488622903823853, 'loudness_essentia': 0.9794596433639526}
# {'file': '/content/drive/MyDrive/all_audio/hiphop.00011.wav', 'tempo': array([135.99917763]), 'energy': 0.20370935, 'loudness_librosa': -53.8918, 'danceability': 1.3588095903396606, 'loudness_essentia': 0.944578230381012}
#                                                   file                 tempo  \
# 0      /content/drive/MyDrive/all_audio/jazz.00097.wav          [86.1328125]
# 1      /content/drive/MyDrive/all_audio/jazz.00068.wav           [73.828125]
# 2      /content/drive/MyDrive/all_audio/jazz.00040.wav   [99.38401442307692]
# 3      /content/drive/MyDrive/all_audio/jazz.00059.wav       [107.666015625]
# 4      /content/drive/MyDrive/all_audio/jazz.00071.wav  [151.99908088235293]
# ..                                                 ...                   ...
# 994  /content/drive/MyDrive/all_audio/hiphop.00004.wav           [95.703125]
# 995  /content/drive/MyDrive/all_audio/hiphop.00038.wav         [184.5703125]
# 996  /content/drive/MyDrive/all_audio/hiphop.00039.wav         [184.5703125]
# 997  /content/drive/MyDrive/all_audio/hiphop.00005.wav         [71.77734375]
# 998  /content/drive/MyDrive/all_audio/hiphop.00011.wav  [135.99917763157896]
#
#        energy  loudness_librosa  danceability  loudness_essentia
# 0    0.021177        -73.377640      1.150778           0.781513
# 1    0.099494        -64.893272      0.957855           0.665984
# 2    0.138014        -63.844234      1.209382           0.965451
# 3    0.182287        -63.590698      1.335253           0.956992
# 4    0.100302        -65.649582      0.903804           0.888091
# ..        ...               ...           ...                ...
# 994  0.200465        -60.065441      1.575762           0.954799
# 995  0.269850        -54.542233      1.321208           0.955486
# 996  0.184495        -55.309654      1.292457           0.942875
# 997  0.261586        -49.798508      1.848862           0.979460
# 998  0.203709        -53.891800      1.358810           0.944578
#
# [999 rows x 6 columns]

# %%
df.to_csv('/content/drive/MyDrive/song_features.csv')

# %%
import numpy as np

# Extract pitch (fundamental frequency) using librosa
pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr)

# Extract the highest magnitude pitch at each time frame
pitch = [np.max(pitches[:, i]) for i in range(pitches.shape[1])]
pitch = [p if p > 0 else np.nan for p in pitch]  # Replace zeros with NaN for clarity
average_pitch = np.nanmean(pitch)  # Average pitch
print('Average Pitch: {:.2f} Hz'.format(average_pitch))
